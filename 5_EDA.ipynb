# %%
import pandas as pd 
import seaborn as sns 

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %matplotlib inline

# %%
df_250 = pd.read_csv('data/3_clean_zomato_gof_250.csv') 

df_250 = df_250[df_250['rating']>0]

# %%
df_250.head()
# Out:
#    index                                                url  rest_price_idr  \
# 0      0  https://www.zomato.com/jakarta/wakacao-1-kelap...          150000
# 1      1  https://www.zomato.com/jakarta/the-coffee-bean...          110000
# 2      2  https://www.zomato.com/jakarta/angke-kelapa-ga...          450000
# 3      3  https://www.zomato.com/jakarta/ikan-nila-pak-u...          100000
# 4      4  https://www.zomato.com/jakarta/hong-kong-sheng...          220000
#
#    review       lat        long  is_chain  rating  new_code_res_type  \
# 0    56.0 -6.167531  106.901752         0     3.8                  4
# 1    61.0 -6.157341  106.907888         1     3.0                  0
# 2   363.0 -6.152638  106.892576         0     4.5                  2
# 3   113.0 -6.163588  106.903689         0     3.9                  0
# 4   257.0 -6.157255  106.908430         1     4.1                  0
#
#    rank_res_type  ...  d_250_mosque  d_250_park d_250_restaurant d_250_school  \
# ...

# %%
df_250.columns
# Out:
# Index(['index', 'url', 'rest_price_idr', 'review', 'lat', 'long', 'is_chain',
#        'rating', 'new_code_res_type', 'rank_res_type', 'new_code_fac',
#        'rank_fac', 'encode', 'geohash', 'd_250_airport', 'd_250_atm',
#        'd_250_bank', 'd_250_cafe', 'd_250_convenience_store',
#        'd_250_gas_station', 'd_250_hospital', 'd_250_lodging',
#        'd_250_meal_takeaway', 'd_250_mosque', 'd_250_park', 'd_250_restaurant',
#        'd_250_school', 'd_250_store', 'd_250_supermarket',
#        'd_250_train_station', 'en_250', 'n_compt_250', 'avg_n_rest'],
#       dtype='object')

# %% [markdown]
# # Restaurant characteristics

# %%
sns.scatterplot(data=df_250, x="rating", y="rest_price_idr")
# sns.regplot(x=df_250["rating"], y=df_250["rest_price_idr"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='rest_price_idr'>

# %%
sns.scatterplot(data=df_250, x="rating", y="rank_fac")

# sns.regplot(x=df_250["rating"], y=df_250["rank_fac"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='rank_fac'>

# %% [markdown]
# # Financial sector

# %%
sns.scatterplot(data=df_250, x="rating", y="d_250_atm")

# sns.regplot(x=df_250["rating"], y=df_250["d_250_atm"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_atm'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.catplot(data=df_250, x="d_250_atm", y="rating", kind="box", height=5, aspect=5)

# %%
sns.scatterplot(data=df_250, x="rating", y="d_250_bank")

# sns.regplot(x=df_250["rating"], y=df_250["d_250_bank"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_bank'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.catplot(data=df_250, x="d_250_bank", y="rating", kind="box", height=5, aspect=5)

# %% [markdown]
# # Transit

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_gas_station"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_gas_station'>

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_train_station"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_train_station'>

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_mosque"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_mosque'>

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_convenience_store"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_convenience_store'>

# %% [markdown]
# # Food

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_meal_takeaway"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_meal_takeaway'>

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_restaurant"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_restaurant'>

# %%
sns.regplot(x=df_250["rating"], y=df_250["d_250_cafe"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_cafe'>

# %% [markdown]
# # Lodging

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.regplot(x=df_250["rating"], y=df_250["d_250_lodging"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='d_250_lodging'>

# %% [markdown]
# # Entropy

# %%
sns.regplot(x=df_250["rating"], y=df_250["en_250"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='en_250'>

# %% [markdown]
# # Competitiveness

# %%
sns.regplot(x=df_250["rating"], y=df_250["n_compt_250"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='n_compt_250'>

# %%
# sns.regplot(x=df_250["rating"], y=df_250["avg_n_rest"])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='avg_n_rest'>
